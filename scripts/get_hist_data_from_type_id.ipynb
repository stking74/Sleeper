# %%
import Sleeper
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
#from umap import UMAP

# %%
app = Sleeper.core.Sleeper()
# Out:
# Initiailizing app...
# Updating swagger...
# Initializing client...
# Refreshing region metadata...

# %%
types = {'Tritanium':34,
         'Pyerite':35,
         'Mexallon':36,
         'Isogen':37,
         'Nocxium':38,
         'Zydrine':39,
         'Megacyte':40,
         'Morphite':18}

history = app.get_regional_history(type_id=[t for t in types.values()])
averages = []
dates = []
for k, tid in types.items():
    averages.append([d['average'] for d in history[tid].data])
    dates.append([str(d['date']) for d in history[tid].data])
    print(k, averages[-1][-1])

plt.figure()
for i, tid in enumerate(types):
    d = dates[i]
    a = averages[i]
    a = [ai / max(a) for ai in a]
    plt.plot(d, a)
plt.legend([k for k in types.keys()])
# Out:
# Tritanium 8.99
# Pyerite 7.28
# Mexallon 69.9
# Isogen 19.46
# Nocxium 313.0
# Zydrine 661.0
# Megacyte 524.97
# Morphite 65.01

# %%
averages[0]
# Out:
# [4.68,
#  4.68,
#  4.76,
#  4.65,
#  4.63,
#  4.65,
#  4.5,
#  4.48,
#  4.51,
#  4.59,
#  4.51,
#  4.59,
#  4.61,
#  4.57,
#  4.46,
#  4.66,
#  4.5,
#  4.49,
#  4.52,
#  4.63,
#  4.63,
#  4.54,
#  4.48,
#  4.65,
#  4.61,
#  4.54,
#  4.54,
#  4.47,
#  4.7,
#  4.63,
#  4.57,
#  4.55,
#  4.55,
#  4.43,
#  4.67,
#  4.55,
#  4.56,
#  4.64,
#  4.61,
#  4.8,
#  4.75,
#  4.75,
#  4.67,
#  4.57,
#  4.54,
#  4.74,
#  4.78,
#  4.68,
#  4.61,
#  4.63,
#  4.73,
#  4.55,
#  4.59,
#  4.76,
#  4.6,
#  4.58,
#  4.63,
#  4.54,
#  4.75,
#  4.65,
#  4.57,
#  4.58,
#  4.58,
#  4.6,
#  4.54,
#  4.53,
#  4.53,
#  4.55,
#  4.55,
#  4.47,
#  4.51,
#  4.59,
#  4.47,
#  4.37,
#  4.49,
#  4.49,
#  4.47,
#  4.48,
#  4.58,
#  4.57,
#  4.6,
#  4.5,
#  4.56,
#  4.6,
#  4.62,
#  4.67,
#  4.69,
#  4.8,
#  4.79,
#  4.8,
#  4.98,
#  5.15,
#  5.09,
#  5.27,
#  5.34,
#  5.26,
#  5.27,
#  5.29,
#  5.39,
#  5.42,
#  5.35,
#  5.28,
#  5.33,
#  5.31,
#  5.4,
#  5.47,
#  5.5,
#  5.96,
#  6.02,
#  6.15,
#  6.08,
#  6.15,
#  6.69,
#  6.63,
#  6.66,
#  6.56,
#  6.6,
#  6.4,
#  6.28,
#  6.27,
#  6.44,
#  6.78,
#  7.0,
#  6.97,
#  6.97,
#  6.97,
#  7.07,
#  7.08,
#  7.07,
#  6.99,
#  7.11,
#  7.0,
#  6.93,
#  6.81,
#  6.71,
#  6.6,
#  6.55,
#  6.64,
#  6.43,
#  6.55,
#  6.55,
#  6.55,
#  6.5,
#  6.49,
#  6.49,
#  6.52,
#  6.4,
#  6.48,
#  6.5,
#  6.49,
#  6.49,
#  6.6,
#  6.6,
#  6.55,
#  6.55,
#  6.69,
#  6.59,
#  6.54,
#  6.82,
#  6.9,
#  7.01,
#  6.91,
#  6.96,
#  6.91,
#  6.84,
#  6.87,
#  6.95,
#  6.93,
#  7.15,
#  6.95,
#  6.99,
#  7.0,
#  6.94,
#  7.13,
#  6.99,
#  7.05,
#  7.06,
#  6.9,
#  6.92,
#  6.9,
#  6.9,
#  6.97,
#  6.83,
#  6.67,
#  6.69,
#  6.85,
#  6.8,
#  6.77,
#  6.7,
#  6.94,
#  6.9,
#  6.85,
#  7.01,
#  6.98,
#  6.98,
#  6.93,
#  6.72,
#  6.79,
#  6.88,
#  6.75,
#  6.74,
#  6.89,
#  6.96,
#  6.86,
#  6.6,
#  6.74,
#  6.64,
#  6.7,
#  6.66,
#  6.52,
#  6.79,
#  6.73,
#  6.74,
#  6.65,
#  6.66,
#  6.39,
#  6.28,
#  6.18,
#  6.14,
#  6.2,
#  6.3,
#  6.08,
#  6.21,
#  6.2,
#  6.24,
#  6.57,
#  6.18,
#  5.75,
#  5.8,
#  5.54,
#  5.42,
#  5.51,
#  5.44,
#  5.47,
#  5.45,
#  5.56,
#  5.25,
#  5.26,
#  5.08,
#  4.9,
#  4.89,
#  5.09,
#  5.13,
#  5.09,
#  4.9,
#  5.13,
#  5.1,
#  5.09,
#  5.39,
#  5.67,
#  5.58,
#  5.26,
#  5.38,
#  5.79,
#  6.1,
#  6.11,
#  5.86,
#  5.63,
#  5.86,
#  5.67,
#  5.3,
#  5.25,
#  5.44,
#  5.6,
#  5.25,
#  5.13,
#  5.08,
#  5.17,
#  5.39,
#  5.44,
#  5.61,
#  5.36,
#  5.24,
#  5.22,
#  5.1,
#  5.1,
#  5.4,
#  5.18,
#  5.08,
#  5.25,
#  5.3,
#  5.15,
#  5.16,
#  5.32,
#  5.23,
#  5.2,
#  5.18,
#  5.25,
#  5.25,
#  5.35,
#  5.54,
#  5.43,
#  5.38,
#  5.46,
#  5.44,
#  5.59,
#  6.35,
#  6.38,
#  6.69,
#  6.48,
#  6.39,
#  6.47,
#  6.42,
#  6.35,
#  6.2,
#  6.15,
#  6.13,
#  6.13,
#  6.17,
#  6.18,
#  6.13,
#  6.35,
#  6.5,
#  6.5,
#  6.5,
#  6.58,
#  6.49,
#  6.48,
#  6.75,
#  6.88,
#  6.45,
#  6.49,
#  6.5,
#  6.76,
#  6.52,
#  6.48,
#  6.4,
#  6.21,
#  6.13,
#  6.14,
#  6.28,
#  6.23,
#  6.17,
#  6.12,
#  6.12,
#  6.26,
#  6.35,
#  6.29,
#  6.46,
#  6.29,
#  6.45,
#  6.25,
#  6.33,
#  6.25,
#  6.2,
#  6.19,
#  6.18,
#  6.46,
#  7.05,
#  7.1,
#  7.16,
#  7.06,
#  7.32,
#  7.12,
#  7.2,
#  7.08,
#  7.24,
#  7.3,
#  7.31,
#  7.68,
#  8.14,
#  7.88,
#  7.9,
#  7.74,
#  7.69,
#  7.68,
#  7.73,
#  7.97,
#  7.94,
#  7.89,
#  7.91,
#  7.84,
#  7.9,
#  8.06,
#  7.85,
#  7.84,
#  7.93,
#  7.99,
#  8.28,
#  8.19,
#  8.23,
#  8.25,
#  8.11,
#  8.03,
#  8.0,
#  8.05,
#  7.64,
#  7.86,
#  7.92,
#  7.72,
#  7.8,
#  8.13,
#  8.29,
#  9.15,
#  9.17,
#  9.23,
#  10.0,
#  10.0,
#  10.0,
#  10.19,
#  9.9,
#  9.43,
#  9.34,
#  9.39,
#  9.5,
#  9.39,
#  9.28,
#  9.11,
#  9.44,
#  9.2,
#  9.28,
#  9.09,
#  8.99]

# %%
types = {'Veldspar':1230,
         'Tritanium':34}

history = app.get_regional_history(type_id=[t for t in types.values()])
averages = []
dates = []
for k, tid in types.items():
    averages.append(np.array([d['average'] for d in history[tid].data]))
    dates.append([str(d['date']) for d in history[tid].data])
    print(k, averages[-1][-1])

plt.figure()
for i, tid in enumerate(types):
    d = dates[i]
    a = averages[i]
    a = a / a.max()
    plt.plot(d, a)
plt.legend([])
plt.show()
# Out:
# Veldspar 23.3
# Tritanium 8.99

# %%
# Out:
# (2,)
